# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\MohammedShadaabKhan\Downloads\world_population.csv")
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0        41128771.00      38972230.00      33753499.00      28189672.00
# 1         2842321.00       2866849.00       2882481.00       2913399.00
# ...

# %%
pd.set_option("display.float_format", lambda x: "%.2f" % x)

# %%
df
# Out:
#      Rank CCA3  Country           Capital Continent  2022 Population  \
# 0      36  AFG      NaN             Kabul      Asia      41128771.00
# 1     138  ALB      NaN            Tirana    Europe       2842321.00
# 2      34  DZA      NaN           Algiers    Africa      44903225.00
# 3     213  ASM      NaN         Pago Pago   Oceania         44273.00
# 4     203  AND      NaN  Andorra la Vella    Europe         79824.00
# ..    ...  ...      ...               ...       ...              ...
# 229   226  WLF      NaN          Mata-Utu   Oceania         11572.00
# 230   172  ESH      NaN          El Aaiún    Africa        575986.00
# 231    46  YEM      NaN             Sanaa      Asia      33696614.00
# 232    63  ZMB      NaN            Lusaka    Africa      20017675.00
# 233    74  ZWE      NaN            Harare    Africa      16320537.00
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# ...

# %%
df.describe()
# Out:
#         Rank  Country  2022 Population  2020 Population  2015 Population  \
# count 234.00     0.00           230.00           233.00           230.00
# mean  117.50      NaN      34632250.88      33600710.95      32066004.16
# std    67.69      NaN     137889172.44     135873196.61     131507146.34
# min     1.00      NaN           510.00           520.00           564.00
# 25%    59.25      NaN        419738.50        406471.00        394295.00
# 50%   117.50      NaN       5762857.00       5456681.00       5244415.00
# 75%   175.75      NaN      22653719.00      21522626.00      19730853.75
# max   234.00      NaN    1425887337.00    1424929781.00    1393715448.00
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count           227.00           227.00           229.00           229.00
# mean       30270164.48      26840495.26      19330463.93      16282884.78
# std       126074183.54     113352454.57      81309624.96      69345465.54
# ...

# %%
df.isnull().sum()
# Out:
# Rank                             0
# CCA3                             0
# Country                        234
# Capital                          0
# Continent                        0
# 2022 Population                  4
# 2020 Population                  1
# 2015 Population                  4
# 2010 Population                  7
# 2000 Population                  7
# 1990 Population                  5
# 1980 Population                  5
# 1970 Population                  4
# Area (km²)                       2
# Density (per km²)                4
# Growth Rate                      2
# World Population Percentage      0
# dtype: int64

# %%
df.nunique()
# Out:
# Rank                           234
# CCA3                           234
# Country                          0
# Capital                        234
# Continent                        6
# 2022 Population                230
# 2020 Population                233
# 2015 Population                230
# 2010 Population                227
# 2000 Population                227
# 1990 Population                229
# 1980 Population                229
# 1970 Population                230
# Area (km²)                     231
# Density (per km²)              230
# Growth Rate                    178
# World Population Percentage     70
# dtype: int64

# %%
df.sort_values(by="2022 Population", ascending=False).head(10)
# Out:
#      Rank CCA3  Country           Capital      Continent  2022 Population  \
# 41      1  CHN      NaN           Beijing           Asia    1425887337.00
# 92      2  IND      NaN         New Delhi           Asia    1417173173.00
# 221     3  USA      NaN  Washington, D.C.  North America     338289857.00
# 93      4  IDN      NaN           Jakarta           Asia     275501339.00
# 156     5  PAK      NaN         Islamabad           Asia     235824862.00
# 149     6  NGA      NaN             Abuja         Africa     218541212.00
# 27      7  BRA      NaN          Brasilia  South America     215313498.00
# 16      8  BGD      NaN             Dhaka           Asia     171186372.00
# 171     9  RUS      NaN            Moscow         Europe     144713314.00
# 131    10  MEX      NaN       Mexico City  North America     127504125.00
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 41     1424929781.00    1393715448.00    1348191368.00    1264099069.00
# ...

# %%
numeric_columns = df.select_dtypes(include=[np.number])
correlation_matrix = numeric_columns.corr
correlation_matrix()
# Out:
#                              Rank  Country  2022 Population  2020 Population  \
# Rank                         1.00      NaN            -0.36            -0.36
# Country                       NaN      NaN              NaN              NaN
# 2022 Population             -0.36      NaN             1.00             1.00
# 2020 Population             -0.36      NaN             1.00             1.00
# 2015 Population             -0.35      NaN             1.00             1.00
# 2010 Population             -0.35      NaN             1.00             1.00
# 2000 Population             -0.34      NaN             0.99             1.00
# 1990 Population             -0.33      NaN             0.99             0.99
# 1980 Population             -0.33      NaN             0.99             0.99
# 1970 Population             -0.34      NaN             0.97             0.98
# Area (km²)                  -0.38      NaN             0.45             0.45
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                              Rank  Country  2022 Population  2020 Population  \
# Rank                         1.00      NaN            -0.36            -0.36
# Country                       NaN      NaN              NaN              NaN
# 2022 Population             -0.36      NaN             1.00             1.00
# 2020 Population             -0.36      NaN             1.00             1.00
# 2015 Population             -0.35      NaN             1.00             1.00
# 2010 Population             -0.35      NaN             1.00             1.00
# 2000 Population             -0.34      NaN             0.99             1.00
# 1990 Population             -0.33      NaN             0.99             0.99
# 1980 Population             -0.33      NaN             0.99             0.99
# 1970 Population             -0.34      NaN             0.97             0.98
# Area (km²)                  -0.38      NaN             0.45             0.45
# ...

# %%
# Assuming you have a DataFrame named df
numeric_df = df.select_dtypes(include='number')  # Select only numeric columns

plt.figure(figsize=(20, 7))  # Set the figure size
sns.heatmap(numeric_df.corr(), annot=True)  # Create the heatmap with annotations

plt.show()  # Display the heatmap

# %%
df.groupby("Continent").mea
# Out:
#      Rank CCA3  Country           Capital Continent  2022 Population  \
# 0      36  AFG      NaN             Kabul      Asia      41128771.00
# 1     138  ALB      NaN            Tirana    Europe       2842321.00
# 2      34  DZA      NaN           Algiers    Africa      44903225.00
# 3     213  ASM      NaN         Pago Pago   Oceania         44273.00
# 4     203  AND      NaN  Andorra la Vella    Europe         79824.00
# ..    ...  ...      ...               ...       ...              ...
# 229   226  WLF      NaN          Mata-Utu   Oceania         11572.00
# 230   172  ESH      NaN          El Aaiún    Africa        575986.00
# 231    46  YEM      NaN             Sanaa      Asia      33696614.00
# 232    63  ZMB      NaN            Lusaka    Africa      20017675.00
# 233    74  ZWE      NaN            Harare    Africa      16320537.00
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# ...

# %%
df2=df.drop(columns=['CCA3','Country','Capital']) 
df3=df2.groupby('Continent').mean(numeric_only=True).sort_values(by="2022 Population",ascending=False)
df3
# Out:
#                 Rank  2022 Population  2020 Population  2015 Population  \
# Continent
# Asia           77.56      96327387.31      94955134.37      89165003.64
# South America  97.57      31201186.29      30823574.50      29509599.71
# Africa         92.16      25455879.68      23871435.26      21419703.57
# Europe        124.50      15055371.82      14915843.92      15027454.12
# North America 160.93      15007403.40      14855914.82      14259596.25
# Oceania       188.52       2046386.32       1910148.96       1756664.48
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Asia               89087770.00      80580835.11      48639995.33
# South America      26789395.54      25015888.69      21224743.93
# Africa             18898197.31      14598365.95      11376964.52
# Europe             14712278.68      14817685.71      14785203.94
# North America      13568016.28      12151739.60      10531660.62
# ...

# %%
df[df["Continent"].str.contains("Oceania")]
# Out:
#      Rank CCA3  Country       Capital Continent  2022 Population  \
# 3     213  ASM      NaN     Pago Pago   Oceania         44273.00
# 11     55  AUS      NaN      Canberra   Oceania      26177413.00
# 44    223  COK      NaN        Avarua   Oceania         17011.00
# 66    162  FJI      NaN          Suva   Oceania        929766.00
# 70    183  PYF      NaN       Papeete   Oceania        306279.00
# 81    191  GUM      NaN       Hagåtña   Oceania        171774.00
# 107   192  KIR      NaN        Tarawa   Oceania        131232.00
# 126   215  MHL      NaN        Majuro   Oceania         41569.00
# 132   194  FSM      NaN       Palikir   Oceania        114164.00
# 142   225  NRU      NaN         Yaren   Oceania         12668.00
# 145   185  NCL      NaN        Nouméa   Oceania        289950.00
# 146   123  NZL      NaN    Wellington   Oceania       5185288.00
# 150   232  NIU      NaN         Alofi   Oceania          1934.00
# ...

# %%
df2.plot()
# Out:
# <Axes: >

# %%
df2.transpose()
# Out:
#                                     0          1           2        3    \
# Rank                                 36        138          34      213
# Continent                          Asia     Europe      Africa  Oceania
# 2022 Population             41128771.00 2842321.00 44903225.00 44273.00
# 2020 Population             38972230.00 2866849.00 43451666.00 46189.00
# 2015 Population             33753499.00 2882481.00 39543154.00 51368.00
# 2010 Population             28189672.00 2913399.00 35856344.00 54849.00
# 2000 Population             19542982.00 3182021.00 30774621.00 58230.00
# 1990 Population             10694796.00 3295066.00 25518074.00 47818.00
# 1980 Population             12486631.00 2941651.00 18739378.00 32886.00
# 1970 Population             10752971.00 2324731.00 13795915.00 27075.00
# Area (km²)                    652230.00   28748.00  2381741.00   199.00
# Density (per km²)                 63.06      98.87       18.85   222.48
# ...

# %%
df.boxplot(figsize=(20,10))
# Out:
# <Axes: >
